# %% [markdown]
# # Yacht Dice RL Training
# **순서:** 셀을 위에서 아래로 순서대로 실행하세요.

# %% [markdown]
# ## 1. Google Drive 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. 코드 다운로드 (GitHub → /content)

# %%
import os

if os.path.exists('/content/18_yacht_dice'):
    print('이미 존재합니다. 최신 코드로 업데이트합니다...')
    # !wget -q https://github.com/scheveningen361/18_yacht_dice/archive/refs/heads/main.zip -O /tmp/repo.zip
    # !unzip -q -o /tmp/repo.zip -d /tmp/
    # !cp -r /tmp/18_yacht_dice-main/* /content/18_yacht_dice/
else:
    print('코드를 다운로드합니다...')
    # !wget -q https://github.com/scheveningen361/18_yacht_dice/archive/refs/heads/main.zip -O /tmp/repo.zip
    # !unzip -q /tmp/repo.zip -d /tmp/
    # !mv /tmp/18_yacht_dice-main /content/18_yacht_dice

print('완료:', os.listdir('/content/18_yacht_dice'))

# %% [markdown]
# ## 3. 의존성 설치

# %%
# !pip install -q gymnasium>=0.29.0 stable-baselines3>=2.3.0 sb3-contrib>=2.3.0 tensorboard

# %% [markdown]
# ## 4. GPU 확인

# %%
import torch
print('CUDA 사용 가능:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %% [markdown]
# ## 5. 학습 실행

# %%
DRIVE_DIR = '/content/drive/MyDrive/yacht_dice'

# !cd /content/18_yacht_dice && python -m rl.train \
  --bc-max-iters 30 \
  --bc-epochs 30 \
  --ppo-steps 5000000 \
  --checkpoint-dir {DRIVE_DIR}/checkpoints \
  --log-dir {DRIVE_DIR}/logs

# %% [markdown]
# ## 6. TensorBoard (선택)

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/yacht_dice/logs
